# %%
from main import build_rag
rag = build_rag()

# Ingest and query (two awaits)
await rag.process_document_complete(
file_path="data/input.txt",
output_dir="./output",
parse_method="auto")

result = await rag.aquery_with_multimodal("WHAT IS AI ?", mode="hybrid")
print(result)
# Out:
# INFO: Created working directory: ./rag_storage_milvus_graph
# INFO: RAGAnything initialized with config:
# INFO:   Working directory: ./rag_storage_milvus_graph
# INFO:   Parser: generic
# INFO:   Parse method: auto
# INFO:   Multimodal processing - Image: True, Table: True, Equation: True
# INFO:   Max concurrent files: 1
# INFO: Parser 'generic' installation verified
# INFO: Initializing LightRAG with parameters: {'working_dir': './rag_storage_milvus_graph', 'graph_storage': 'Neo4JStorage', 'vector_storage': 'MilvusVectorDBStorage'}
# INFO: [_] Process 84194 KV load full_docs with 0 records
# INFO: [_] Process 84194 KV load text_chunks with 0 records
# INFO: [_] Process 84194 KV load full_entities with 0 records
# INFO: [_] Process 84194 KV load full_relations with 0 records
# INFO: [_] Process 84194 KV load entity_chunks with 0 records
# INFO: [_] Process 84194 KV load relation_chunks with 0 records
# INFO: [_] VectorDB collection 'entities' exists check: True
# ...

# %%
from main import build_rag
rag = build_rag()

# Ingest and query (two awaits)
await rag.process_document_complete(
file_path="data/image.png",
output_dir="./output",
parse_method="auto")

result = await rag.aquery_with_multimodal("Which fruites have yellow in color ?", mode="hybrid")
print(result)
# Out:
# INFO: RAGAnything initialized with config:
# INFO:   Working directory: ./rag_storage_milvus_graph
# INFO:   Parser: generic
# INFO:   Parse method: auto
# INFO:   Multimodal processing - Image: True, Table: True, Equation: True
# INFO:   Max concurrent files: 1
# INFO: Parser 'generic' installation verified
# INFO: Initializing LightRAG with parameters: {'working_dir': './rag_storage_milvus_graph', 'graph_storage': 'Neo4JStorage', 'vector_storage': 'MilvusVectorDBStorage'}
# INFO: [_] Process 84908 KV load full_docs with 1 records
# INFO: [_] Process 84908 KV load text_chunks with 2 records
# INFO: [_] Process 84908 KV load full_entities with 2 records
# INFO: [_] Process 84908 KV load full_relations with 2 records
# INFO: [_] Process 84908 KV load entity_chunks with 18 records
# INFO: [_] Process 84908 KV load relation_chunks with 13 records
# INFO: [_] VectorDB collection 'entities' exists check: True
# INFO: [_] VectorDB Collection 'entities' compatibility validation passed
# ...

# %%
from main import build_rag
rag = build_rag()

# Ingest and query (two awaits)
await rag.process_document_complete(
file_path="data/doc.pdf",
output_dir="./output",
parse_method="auto")

result = await rag.aquery_with_multimodal("What is google adk and how can we connect it to langgraph ?", mode="hybrid")
print(result)
# Out:
# INFO: RAGAnything initialized with config:
# INFO:   Working directory: ./rag_storage_milvus_graph
# INFO:   Parser: generic
# INFO:   Parse method: auto
# INFO:   Multimodal processing - Image: True, Table: True, Equation: True
# INFO:   Max concurrent files: 1
# INFO: Parser 'generic' installation verified
# INFO: Initializing LightRAG with parameters: {'working_dir': './rag_storage_milvus_graph', 'graph_storage': 'Neo4JStorage', 'vector_storage': 'MilvusVectorDBStorage'}
# INFO: [_] VectorDB collection 'entities' exists check: True
# INFO: [_] VectorDB Collection 'entities' compatibility validation passed
# INFO: [_] Milvus collection 'entities' initialized successfully
# INFO: [_] VectorDB collection 'relationships' exists check: True
# INFO: [_] VectorDB Collection 'relationships' compatibility validation passed
# INFO: [_] Milvus collection 'relationships' initialized successfully
# INFO: [_] VectorDB collection 'chunks' exists check: True
# ...

# %% [markdown]
# ### AFTER PROCESSING ALL DOCS WE CAN NOW QUERY DIRECTLY WITHOUT PROCESSING DOCS.

# %%
from main import build_rag
rag = build_rag()

result = await rag.aquery_with_multimodal("What is google adk AND how is it related to AI also tell me what is the no of fruites present here?", mode="hybrid")
print(result)
# Out:
# INFO: RAGAnything initialized with config:
# INFO:   Working directory: ./rag_storage_milvus_graph
# INFO:   Parser: generic
# INFO:   Parse method: auto
# INFO:   Multimodal processing - Image: True, Table: True, Equation: True
# INFO:   Max concurrent files: 1
# INFO: Parser 'generic' installation verified
# INFO: Initializing LightRAG with parameters: {'working_dir': './rag_storage_milvus_graph', 'graph_storage': 'Neo4JStorage', 'vector_storage': 'MilvusVectorDBStorage'}
# INFO: [_] VectorDB collection 'entities' exists check: True
# INFO: [_] VectorDB Collection 'entities' compatibility validation passed
# INFO: [_] Milvus collection 'entities' initialized successfully
# INFO: [_] VectorDB collection 'relationships' exists check: True
# INFO: [_] VectorDB Collection 'relationships' compatibility validation passed
# INFO: [_] Milvus collection 'relationships' initialized successfully
# INFO: [_] VectorDB collection 'chunks' exists check: True
# ...

# %%
from main import build_rag
rag = build_rag()

result = await rag.aquery_with_multimodal("What is image about explain and where its data is being stored and why iis it abel to sstored as graph in neo4j", mode="hybrid")
print(result)
# Out:
# INFO: RAGAnything initialized with config:
# INFO:   Working directory: ./rag_storage_milvus_graph
# INFO:   Parser: generic
# INFO:   Parse method: auto
# INFO:   Multimodal processing - Image: True, Table: True, Equation: True
# INFO:   Max concurrent files: 1
# INFO: Parser 'generic' installation verified
# INFO: Initializing LightRAG with parameters: {'working_dir': './rag_storage_milvus_graph', 'graph_storage': 'Neo4JStorage', 'vector_storage': 'MilvusVectorDBStorage'}
# INFO: [_] VectorDB collection 'entities' exists check: True
# INFO: [_] VectorDB Collection 'entities' compatibility validation passed
# INFO: [_] Milvus collection 'entities' initialized successfully
# INFO: [_] VectorDB collection 'relationships' exists check: True
# INFO: [_] VectorDB Collection 'relationships' compatibility validation passed
# INFO: [_] Milvus collection 'relationships' initialized successfully
# INFO: [_] VectorDB collection 'chunks' exists check: True
# ...
